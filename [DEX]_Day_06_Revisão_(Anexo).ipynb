# %% [markdown]
# <a href="https://colab.research.google.com/github/michellssGUi/conciergeControl/blob/master/%5BDEX%5D_Day_06_Revis%C3%A3o_(Anexo).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaad = files.upload()
# Out:
#      <input type="file" id="files-92e2aa51-afb6-4034-b639-3b8f2f3fde57" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92e2aa51-afb6-4034-b639-3b8f2f3fde57">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-da4cd7e9d697> in <module>()
#       1 from google.colab import files
# ----> 2 uploaad = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      44   """
#      45
# ---> 46   uploaded_files = _upload_files(multiple=True)
#      47   # Mapping from original filename to filename as saved locally.
#      48   local_filenames = dict()
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DataPrepFinal.csv').drop(columns=['Unnamed: 0'])
dfC = pd.read_csv('campaign.csv')
dfI = pd.read_csv('invested.csv')

# %%
df.head()
# Out:
#            ID  ... usd_goal_real
# 0  1000002330  ...    USD 153395
# 1  1000003930  ...   USD 3000000
# 2  1000004038  ...   USD 4500000
# 3  1000007540  ...    USD 500000
# 4  1000011046  ...   USD 1950000
#
# [5 rows x 15 columns]

# %%
dfC.head()
# Out:
#            ID  Text Description  Video  Image  Infographic  Reviews  Risks
# 0  1000002330                 1      1      1            1        0      1
# 1  1000003930                 1      1      1            1        1      0
# 2  1000004038                 1      0      1            1        0      1
# 3  1000007540                 1      1      0            1        0      0
# 4  1000011046                 1      0      1            0        0      0

# %%
dfI.head()
# Out:
#            ID backedLocation  age
# 0  1000003930             BR   18
# 1  1000004038             US   57
# 2  1000007540             US   43
# 3  1000011046             BR   29
# 4  1000014025             BR   77

# %% [markdown]
# # ESTRUTURAÇÃO DOS DADOS

# %% [markdown]
# ##DUPLICADOS
#
#
# Verificar se existem dados duplicados

# %%
dfI.duplicated().sum()
# Out:
# 119

# %% [markdown]
# Remover dados duplicados

# %%
dfI = dfI.drop_duplicates()

# %%
dfI.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##LAMBDA
#
# É uma função que executa uma ação para cada elemento de uma coluna.

# %%
df['state'].unique()
# Out:
# array(['failed', 'canceled', 'successful', 'live', 'undefined',
#        'suspended', nan], dtype=object)

# %%
df['state'] = df['state'].apply(lambda x: True if x=='successful' else False)

# %%
df['state'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# ##Merge

# %%
df = df.merge(dfC, how='right',on='ID')

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency  deadline       goal        launched  \
# 0          Poetry    Publishing      GBP  09/10/15   100000.0  11/08/15 12:12
# 1  Narrative Film  Film & Video      USD  01/11/17  3000000.0  02/09/17 04:43
# 2  Narrative Film  Film & Video      USD  26/02/13  4500000.0  12/01/13 00:20
# 3           Music         Music      USD  16/04/12   500000.0  17/03/12 03:24
# 4    Film & Video  Film & Video      USD  29/08/15  1950000.0  04/07/15 08:35
#
#     pledged  state  ...  country usd pledged  usd_pledged_real  usd_goal_real  \
# ...

# %% [markdown]
# # LOC
#
# Selecionar uma parte, uma matrix do seu Dataframe.

# %%
df_target = df.loc[df.state==True]

# %%
df_target.head()
# Out:
#             ID                                               name  \
# 5   1000014025                               Monarch Espresso Bar
# 6   1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 11   100005484                                   Lisa Lim New CD!
# 14  1000057089  Tombstone: Old West tabletop game and miniatur...
# 18  1000070642                Mike Corey's Darkness & Light Album
#
#           category main_category currency  deadline       goal  \
# 5      Restaurants          Food      USD  01/04/16  5000000.0
# 6             Food          Food      USD  21/12/14   100000.0
# 11      Indie Rock         Music      USD  08/04/13  1250000.0
# 14  Tabletop Games         Games      GBP  03/05/17   500000.0
# 18           Music         Music      USD  17/08/12    25000.0
#
#           launched    pledged state  ...  country usd pledged  \
# 5   26/02/16 13:38  5237500.0  True  ...       US   5237500.0
# ...

# %% [markdown]
# ## ONE HOT ENCONGIND
#
# Transformar as variaveis cat em int.

# %%
dfI.head()
# Out:
#            ID backedLocation  age
# 0  1000003930             BR   18
# 1  1000004038             US   57
# 2  1000007540             US   43
# 3  1000011046             BR   29
# 4  1000014025             BR   77

# %%
dfI = pd.get_dummies(dfI, columns= ['backedLocation'])

# %%
dfI.head()
# Out:
#            ID  age  backedLocation_BR  backedLocation_GBK  backedLocation_US
# 0  1000003930   18                  1                   0                  0
# 1  1000004038   57                  0                   0                  1
# 2  1000007540   43                  0                   0                  1
# 3  1000011046   29                  1                   0                  0
# 4  1000014025   77                  1                   0                  0

# %% [markdown]
# ## GROUPBY e AGG

# %%
dfI = dfI.groupby(by=['ID']).agg({'age': 'mean', 'backedLocation_BR': 'sum', 'backedLocation_GBK': 'sum','backedLocation_US':'sum'})

# %%
dfI.head()
# Out:
#           age  backedLocation_BR  backedLocation_GBK  backedLocation_US
# ID
# 106144   66.5                  0                   1                  1
# 1003381  48.5                  1                   0                  1
# 1017454  41.5                  0                   0                  2
# 1024013  77.0                  2                   0                  0
# 1024208  71.0                  0                   1                  1

# %% [markdown]
# # TRATAMENTO DOS DADOS

# %% [markdown]
# ##TRATAMENTO DE NULOS

# %% [markdown]
# Verificar nulos
# Indentifica qual tipo de nulo
# Como tratar

# %%
df['usd pledged'].value_counts(dropna=False)
# Out:
# NaN          5671
# 0.0          2438
# 100.0         183
# 2500.0        154
# 1000.0        137
#              ...
# 3623700.0       1
# 204500.0        1
# 1212500.0       1
# 3062900.0       1
# 62100.0         1
# Name: usd pledged, Length: 6882, dtype: int64

# %%
df['usd pledged'].isna().value_counts()
# Out:
# False    13792
# True      5671
# Name: usd pledged, dtype: int64

# %%
df.loc[df['usd pledged'].isna(), 'usd pledged'] ==0
# Out:
# 169      False
# 328      False
# 632      False
# 647      False
# 749      False
#          ...
# 19458    False
# 19459    False
# 19460    False
# 19461    False
# 19462    False
# Name: usd pledged, Length: 5671, dtype: bool

# %% [markdown]
# ##OUTLIERS

# %% [markdown]
# IQR
#
# Media +-3 STD

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df.describe(percentiles=[0.01, 0.1, 0.25, 0.5, 0.75, 0.90, 0.99])
# Out:
#                     ID             goal         pledged     backers  \
# count      19463.00000      13938.00000     13937.00000 13937.00000
# mean   953374042.74958    3625777.20283   1045868.40102   104.91512
# std    288303412.97154   46618014.73446  11432442.80847   837.53470
# min       106144.00000        100.00000         0.00000     0.00000
# 1%      10852768.42000       5000.00000         0.00000     0.00000
# 10%    109803027.40000      60000.00000         0.00000     0.00000
# 25%   1016755687.50000     200000.00000      3200.00000     2.00000
# 50%   1043572452.00000     500000.00000     62600.00000    12.00000
# 75%   1070562092.00000    1700000.00000    411443.00000    55.00000
# 90%   1087861757.20000    5000000.00000   1452462.20000   159.00000
# 99%   1097605778.62000   35000000.00000  12913010.36000  1522.40000
# max   1098735707.00000 4000000000.00000 859647458.00000 63416.00000
#
#           usd pledged  usd_pledged_real  Text Description       Video  \
# ...

# %%
limitesuperior = df['usd_pledged_real'].mean() + 3*df['usd_pledged_real'].std()

# %%
print(limitesuperior)
# Out:
# 34377072.11683259

# %% [markdown]
# TRATAR OUTLIER
#
# REMOVE, CAP( MAX, MIN), PREENCHER COM MÉDIA, COM MODA.

# %%
df['usd_pledged_real']   =   df['usd_pledged_real'].apply(lambda x: limitesuperior if x>= limitesuperior else x)

# %% [markdown]
# # ENRIQUECIMENTO DOS DADOS

# %% [markdown]
# CONSTRUÇÃO DE ALGUM DADO NOVO
#
# CRIAÇÃO CATEGORIAS OU SUBCATEGORIAS

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency  deadline          goal  \
# 0          Poetry    Publishing      GBP  09/10/15  100000.00000
# 1  Narrative Film  Film & Video      USD  01/11/17 3000000.00000
# 2  Narrative Film  Film & Video      USD  26/02/13 4500000.00000
# 3           Music         Music      USD  16/04/12  500000.00000
# 4    Film & Video  Film & Video      USD  29/08/15 1950000.00000
#
#          launched      pledged  state  ...  country  usd pledged  \
# 0  11/08/15 12:12      0.00000  False  ...       GB      0.00000
# ...

# %%
df['deadline'] = pd.to_datetime(df['deadline'], format= '%d/%m/%y')
df['launched'] = pd.to_datetime(df['launched'], format= '%d/%m/%y %h:%m')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-5d03a828cb0f> in <module>()
#       1 df['deadline'] = pd.to_datetime(df['deadline'], format= '%d/%m/%y')
# ...

# %%
df['date_range'] = (df['deadline'] - df['launched']).dt.days
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimelike.py:1190: PerformanceWarning: Adding/subtracting object-dtype array to DatetimeArray not vectorized
#   PerformanceWarning,
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-abb3d5a5742e> in <module>()
# ----> 1 df['date_range'] = (df['deadline'] - df['launched']).dt.days
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __sub__(self, other)
#      98     @unpack_zerodim_and_defer("__sub__")
#      99     def __sub__(self, other):
# --> 100         return self._arith_method(other, operator.sub)
#     101
# ...

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline          goal  \
# 0          Poetry    Publishing      GBP 2015-10-09  100000.00000
# 1  Narrative Film  Film & Video      USD 2017-11-01 3000000.00000
# 2  Narrative Film  Film & Video      USD 2013-02-26 4500000.00000
# 3           Music         Music      USD 2012-04-16  500000.00000
# 4    Film & Video  Film & Video      USD 2015-08-29 1950000.00000
#
#          launched      pledged  state  ...  country  usd pledged  \
# 0  11/08/15 12:12      0.00000  False  ...       GB      0.00000
# ...

# %% [markdown]
# # VALIDAÇÃO E PIPELINE

# %% [markdown]
# VALIDAÇÃO
#
# Checklist:
# 1. Valida se existem dados nulos
# 2. Validar a tratamento
# 3. Validar se existem Outliers

# %% [markdown]
# ##PIPELINE

# %%
def load_data():
  df_final = pd.read_csv('DataPrepFinal.csv').drop(columns=['Unnamed: 0'])
  return df_final

# %%
def create_target_state(df_final):
  df_final['state'] = df_final['state'].apply(lambda x: True if x=='successful' else False)
  df_target_final = df_final.loc[df_final.state==True]
  return df_target_final

# %%
def categoryToBoll(dfI):
  dfI_final = pd.get_dummies(dfI, columns= ['backedLocation'])
  return dfI_final

# %%
pipeline = (
    load_data()
    .pipe(create_target_state)
)

# %%
pipeline.head()
# Out:
#             ID                                               name  \
# 5   1000014025                               Monarch Espresso Bar
# 6   1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 11   100005484                                   Lisa Lim New CD!
# 14  1000057089  Tombstone: Old West tabletop game and miniatur...
# 18  1000070642                Mike Corey's Darkness & Light Album
#
#           category main_category currency  deadline     goal        launched  \
# 5      Restaurants          Food      USD  01/04/16  5000000  26/02/16 13:38
# 6             Food          Food      USD  21/12/14   100000  01/12/14 18:30
# 11      Indie Rock         Music      USD  08/04/13  1250000  09/03/13 06:42
# 14  Tabletop Games         Games      GBP  03/05/17   500000  05/04/17 19:44
# 18           Music         Music      USD  17/08/12    25000  02/08/12 14:11
#
#     pledged  state  backers country   usd pledged  usd_pledged_real  \
# ...
